# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df
# Out:
#       show_id     type                  title         director  \
# 0           1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           2  TV Show          Blood & Water              NaN
# 2           3  TV Show              Ganglands  Julien Leclercq
# 3           4  TV Show  Jailbirds New Orleans              NaN
# 4           5  TV Show           Kota Factory              NaN
# ...       ...      ...                    ...              ...
# 8802     8803    Movie                 Zodiac    David Fincher
# 8803     8804  TV Show            Zombie Dumb              NaN
# 8804     8805    Movie             Zombieland  Ruben Fleischer
# 8805     8806    Movie                   Zoom     Peter Hewitt
# 8806     8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   int64
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 825.8+ KB

# %%
for i in df.columns:
    null_rate = df[i].isna().sum() / len(df) * 100 
    if null_rate > 0 :
        print("{} null rate: {}%".format(i,round(null_rate,2)))
# Out:
# director null rate: 29.91%
# cast null rate: 9.37%
# country null rate: 9.44%
# date_added null rate: 0.11%
# rating null rate: 0.05%
# duration null rate: 0.03%

# %%
df.drop(["director", "cast", "date_added", "description"], axis=1, inplace=True)

# %%
df
# Out:
#       show_id     type                  title        country  release_year  \
# 0           1    Movie   Dick Johnson Is Dead  United States          2020
# 1           2  TV Show          Blood & Water   South Africa          2021
# 2           3  TV Show              Ganglands            NaN          2021
# 3           4  TV Show  Jailbirds New Orleans            NaN          2021
# 4           5  TV Show           Kota Factory          India          2021
# ...       ...      ...                    ...            ...           ...
# 8802     8803    Movie                 Zodiac  United States          2007
# 8803     8804  TV Show            Zombie Dumb            NaN          2018
# 8804     8805    Movie             Zombieland  United States          2009
# 8805     8806    Movie                   Zoom  United States          2006
# 8806     8807    Movie                 Zubaan          India          2015
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   int64
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   country       7976 non-null   object
#  4   release_year  8807 non-null   int64
#  5   rating        8803 non-null   object
#  6   duration      8804 non-null   object
#  7   listed_in     8807 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 550.6+ KB

# %%
df["country"] = df["country"].fillna("unknown")
df["rating"] = df["rating"].fillna("unknown")
df["duration"] = df["duration"].fillna("unknown")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   int64
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   country       8807 non-null   object
#  4   release_year  8807 non-null   int64
#  5   rating        8807 non-null   object
#  6   duration      8807 non-null   object
#  7   listed_in     8807 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 550.6+ KB

# %%
df.to_csv('netflix_titles_edited.csv', index=False)

# %%
df
# Out:
#       show_id     type                  title        country  release_year  \
# 0           1    Movie   Dick Johnson Is Dead  United States          2020
# 1           2  TV Show          Blood & Water   South Africa          2021
# 2           3  TV Show              Ganglands        unknown          2021
# 3           4  TV Show  Jailbirds New Orleans        unknown          2021
# 4           5  TV Show           Kota Factory          India          2021
# ...       ...      ...                    ...            ...           ...
# 8802     8803    Movie                 Zodiac  United States          2007
# 8803     8804  TV Show            Zombie Dumb        unknown          2018
# 8804     8805    Movie             Zombieland  United States          2009
# 8805     8806    Movie                   Zoom  United States          2006
# 8806     8807    Movie                 Zubaan          India          2015
#
# ...

# %%
conn = sqlite3.connect('netflix_titles.db')

# %%
create_sql = "CREATE TABLE IF NOT EXISTS shows_and_movies (show_id INTEGER PRIMARY KEY, type TEXT, title TEXT, country TEXT, release_year TEXT, rating TEXT, duration TEXT, listed_in TEXT)"

# %%
cursor = conn.cursor()

# %%
cursor.execute(create_sql)

# %%
# for row in df.itertuples():
#     insert_sql = f"INSERT INTO shows_and_movies (show_id, type, title, country, release_year, rating, duration, listed_in) VALUES ({row[1]}, '{row[2]}', '{row[3]}', '{row[4]}', '{row[5]}', '{row[6]}', '{row[7]}', '{row[8]}')"
#     cursor.execute(insert_sql)

# %%
df.to_sql(name="shows_and_movies", con=conn, dtype={'show_id': 'INTEGER PRIMARY KEY',
                                                    'type': 'TEXT',
                                                    'title': 'TEXT',
                                                    'country': 'TEXT',
                                                    'release_year': 'INTEGER',
                                                    'rating': 'TEXT',
                                                    'duration': 'TEXT',
                                                    'listed_in': 'TEXT'}, if_exists="replace", index=False)
